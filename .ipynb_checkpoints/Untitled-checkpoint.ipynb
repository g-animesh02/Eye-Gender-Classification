# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import matplotlib.image as img

# %%
import tensorflow as tf
import cv2
from keras.layers import Conv2D,Dropout,Dense,Flatten,Conv2DTranspose,BatchNormalization,LeakyReLU,Reshape
from keras.models import Sequential

# %%
train_label = pd.read_csv("eye_gender_data/Training_set.csv")
test_label_pred = pd.read_csv("eye_gender_data/Testing_set.csv")

# %%
train_label.head()
# Out:
#       filename   label
# 0  Image_1.jpg    male
# 1  Image_2.jpg  female
# 2  Image_3.jpg  female
# 3  Image_4.jpg  female
# 4  Image_5.jpg    male

# %%
test_label_pred.head()
# Out:
#       filename
# 0  Image_1.jpg
# 1  Image_2.jpg
# 2  Image_3.jpg
# 3  Image_4.jpg
# 4  Image_5.jpg

# %%
from sklearn.preprocessing import LabelEncoder

labelEncoder = LabelEncoder()
labels = labelEncoder.fit_transform(train_label.label)
train_label.label = labels

# %%
train_label.head()
#1 for male and 0 for female
# Out:
#       filename  label
# 0  Image_1.jpg      1
# 1  Image_2.jpg      0
# 2  Image_3.jpg      0
# 3  Image_4.jpg      0
# 4  Image_5.jpg      1

# %%
X_train = []
c = 0
for i in range(train_label.shape[0]):
    image = cv2.imread("eye_gender_data/train/" + train_label.filename[i], cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (50,50))
    image = image/255
    X_train.append(image)
    c += 1
    if c%100 == 0:
        print(str(c) + " training images imported")
# Out:
# 100 training images imported
# 200 training images imported
# 300 training images imported
# 400 training images imported
# 500 training images imported
# 600 training images imported
# 700 training images imported
# 800 training images imported
# 900 training images imported
# 1000 training images imported
# 1100 training images imported
# 1200 training images imported
# 1300 training images imported
# 1400 training images imported
# 1500 training images imported
# 1600 training images imported
# 1700 training images imported
# 1800 training images imported
# 1900 training images imported
# 2000 training images imported
# 2100 training images imported
# 2200 training images imported
# 2300 training images imported
# 2400 training images imported
# 2500 training images imported
# 2600 training images imported
# 2700 training images imported
# 2800 training images imported
# 2900 training images imported
# 3000 training images imported
# 3100 training images imported
# ...

# %%
X = np.array(X_train)

# %%
X.shape
# Out:
# (9220, 50, 50, 3)

# %%
train_images = X.reshape(X.shape[0], 50, 50, 3)

# %%
train_images.shape
# Out:
# (9220, 50, 50, 3)

# %%
X_test = []
c = 0
for i in range(test_label_pred.shape[0]):
    image = cv2.imread("eye_gender_data/test/" + test_label_pred.filename[i], cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (50,50))
    image = image/255
    X_test.append(image)
    c += 1
    if c%100 == 0:
        print(str(c) + " testing images imported")
# Out:
# 100 testing images imported
# 200 testing images imported
# 300 testing images imported
# 400 testing images imported
# 500 testing images imported
# 600 testing images imported
# 700 testing images imported
# 800 testing images imported
# 900 testing images imported
# 1000 testing images imported
# 1100 testing images imported
# 1200 testing images imported
# 1300 testing images imported
# 1400 testing images imported
# 1500 testing images imported
# 1600 testing images imported
# 1700 testing images imported
# 1800 testing images imported
# 1900 testing images imported
# 2000 testing images imported
# 2100 testing images imported
# 2200 testing images imported
# 2300 testing images imported

# %%
T = np.array(X_test)
test_images = T.reshape(T.shape[0], 50, 50, 3)

# %%
test_images.shape
# Out:
# (2305, 50, 50, 3)

# %%
INPUT_SHAPE = (50, 50, 3)

# define sequential model
model = tf.keras.models.Sequential()
# define conv-pool layers - set 1
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1),
activation='relu', padding='valid', input_shape=INPUT_SHAPE))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
# define conv-pool layers - set 2
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1),
activation='relu', padding='valid', input_shape=INPUT_SHAPE))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Flatten())

# add dense layers with some dropout
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.3))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.3))

# add output layer
model.add(tf.keras.layers.Dense(2, activation='softmax'))

# compile model
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])

# view model layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 48, 48, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3872)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               991488
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# ...

# %%
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2,
restore_best_weights=True,
verbose=1)

# %%
history = model.fit(train_images, train_label.label,
batch_size=32,
callbacks=[es_callback],
validation_split=0.1, epochs=100,
verbose=1)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 10s 36ms/step - loss: 0.4504 - accuracy: 0.7836 - val_loss: 0.3245 - val_accuracy: 0.8633
# Epoch 2/100
# 260/260 [==============================] - 9s 35ms/step - loss: 0.3040 - accuracy: 0.8744 - val_loss: 0.3572 - val_accuracy: 0.8416
# Epoch 3/100
# 260/260 [==============================] - 9s 35ms/step - loss: 0.2489 - accuracy: 0.8995 - val_loss: 0.2845 - val_accuracy: 0.8742
# Epoch 4/100
# 260/260 [==============================] - 9s 36ms/step - loss: 0.2153 - accuracy: 0.9140 - val_loss: 0.2842 - val_accuracy: 0.8894
# Epoch 5/100
# 260/260 [==============================] - 9s 36ms/step - loss: 0.1939 - accuracy: 0.9223 - val_loss: 0.2341 - val_accuracy: 0.9002
# Epoch 6/100
# 260/260 [==============================] - 9s 36ms/step - loss: 0.1802 - accuracy: 0.9264 - val_loss: 0.2101 - val_accuracy: 0.9078
# Epoch 7/100
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot(kind='line', ax=ax[0])
history_df[['accuracy', 'val_accuracy']].plot(kind='line', ax=ax[1]);

# %%
prob = model.predict(test_images)

p = np.argmax(prob, axis=1)

pred = labelEncoder.inverse_transform(p)

test_label_pred['label'] = pred

test_label_pred.head()
# Out:
#       filename label label_pred
# 0  Image_1.jpg  male       male
# 1  Image_2.jpg  male       male
# 2  Image_3.jpg  male       male
# 3  Image_4.jpg  male       male
# 4  Image_5.jpg  male       male

# %%
test_label_pred.label.value_counts()
# Out:
# male      1258
# female    1047
# Name: label, dtype: int64

# %%
test_label_pred.label.to_csv("output.csv", columns=['label'], index=False)

# %%
INPUT_SHAPE = (50, 50, 3)

# get the VGG19 model
vgg_layers = tf.keras.applications.vgg19.VGG19(weights='imagenet', include_top=False,
input_shape=INPUT_SHAPE)

vgg_layers.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 50, 50, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 50, 50, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 50, 50, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 25, 25, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 25, 25, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 25, 25, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 12, 12, 128)       0
# ...

# %%
for layer in vgg_layers.layers:
    layer.trainable = True

# Check the trainable status of the individual layers
for layer in vgg_layers.layers:
    print(layer, layer.trainable)
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x0000013D9A77F370> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9EEF8100> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A4C2C70> True
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000013D9A48D190> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A7151C0> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A0B3F40> True
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000013D9A4A8670> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A4A8BE0> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A4B8B50> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A4BE2B0> True
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000013D9A4B4BB0> True
# ...

# %%
model = tf.keras.models.Sequential()

# Add the vgg convolutional base model
model.add(vgg_layers)

# add flatten layer
model.add(tf.keras.layers.Flatten())

# add dense layers with some dropout
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.3))
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.3))

# add output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])

# view model layers
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                2570
# ...

# %%
EPOCHS = 100
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2,
restore_best_weights=True,
verbose=1)

history = model.fit(train_images, train_label.label,
batch_size=32,
callbacks=[es_callback],
validation_split=0.1, epochs=EPOCHS,
verbose=1)
# Out:
# Epoch 1/100
# 260/260 [==============================] - 849s 3s/step - loss: 0.5240 - accuracy: 0.7971 - val_loss: 0.1815 - val_accuracy: 0.9306
# Epoch 2/100
# 260/260 [==============================] - 857s 3s/step - loss: 0.2062 - accuracy: 0.9271 - val_loss: 0.1615 - val_accuracy: 0.9382
# Epoch 3/100
# 260/260 [==============================] - 874s 3s/step - loss: 0.1439 - accuracy: 0.9488 - val_loss: 0.2157 - val_accuracy: 0.9132
# Epoch 4/100
# 260/260 [==============================] - 875s 3s/step - loss: 0.1095 - accuracy: 0.9607 - val_loss: 0.1387 - val_accuracy: 0.9555
# Epoch 5/100
# 260/260 [==============================] - 877s 3s/step - loss: 0.0852 - accuracy: 0.9696 - val_loss: 0.1631 - val_accuracy: 0.9436
# Epoch 6/100
# 260/260 [==============================] - 877s 3s/step - loss: 0.0733 - accuracy: 0.9731 - val_loss: 0.1565 - val_accuracy: 0.9501
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot(kind='line', ax=ax[0])
history_df[['accuracy', 'val_accuracy']].plot(kind='line', ax=ax[1]);

# %%
prob2 = model.predict(test_images)

pr = np.argmax(prob2, axis=1)

pred2 = labelEncoder.inverse_transform(pr)

test_label_pred['label_pred'] = pred2

test_label_pred.head()
# Out:
#       filename label label_pred
# 0  Image_1.jpg  male       male
# 1  Image_2.jpg  male       male
# 2  Image_3.jpg  male       male
# 3  Image_4.jpg  male       male
# 4  Image_5.jpg  male       male

# %%
test_label_pred.label_pred.value_counts()
# Out:
# male      1339
# female     966
# Name: label_pred, dtype: int64

# %%
test_label_pred.label_pred.to_csv("output2.csv", columns=['label_pred'], index=False)

# %%
prob
# Out:
# array([[2.14876150e-06, 9.99997377e-01, 5.62927447e-08, ...,
#         4.28962217e-08, 3.12019246e-08, 4.14276258e-08],
#        [1.51318476e-01, 8.44543815e-01, 6.60854043e-04, ...,
#         4.28041501e-04, 3.96241929e-04, 2.93181161e-04],
#        [6.28803205e-03, 9.92978513e-01, 1.07346495e-04, ...,
#         5.29930476e-05, 7.63172648e-05, 4.45187361e-05],
#        ...,
#        [1.50558717e-05, 9.99981046e-01, 3.47714149e-07, ...,
#         2.67029918e-07, 2.66100272e-07, 2.75741627e-07],
#        [1.93367077e-06, 9.99997377e-01, 5.44492522e-08, ...,
#         5.63030511e-08, 4.19277981e-08, 5.05430435e-08],
#        [1.56232649e-02, 9.83280957e-01, 1.61483258e-04, ...,
#         9.05840716e-05, 9.95762748e-05, 6.11929645e-05]], dtype=float32)

# %%
prob2
# Out:
# array([[2.14876150e-06, 9.99997377e-01, 5.62927447e-08, ...,
#         4.28962217e-08, 3.12019246e-08, 4.14276258e-08],
#        [1.51318476e-01, 8.44543815e-01, 6.60854043e-04, ...,
#         4.28041501e-04, 3.96241929e-04, 2.93181161e-04],
#        [6.28803205e-03, 9.92978513e-01, 1.07346495e-04, ...,
#         5.29930476e-05, 7.63172648e-05, 4.45187361e-05],
#        ...,
#        [1.50558717e-05, 9.99981046e-01, 3.47714149e-07, ...,
#         2.67029918e-07, 2.66100272e-07, 2.75741627e-07],
#        [1.93367077e-06, 9.99997377e-01, 5.44492522e-08, ...,
#         5.63030511e-08, 4.19277981e-08, 5.05430435e-08],
#        [1.56232649e-02, 9.83280957e-01, 1.61483258e-04, ...,
#         9.05840716e-05, 9.95762748e-05, 6.11929645e-05]], dtype=float32)

# %%
pr2 = np.argmax((prob+prob2)/2, axis=1)

# %%
pred3 = labelEncoder.inverse_transform(pr2)

test_label_pred['label_pred3'] = pred3

test_label_pred.head()
# Out:
#       filename label label_pred label_pred3
# 0  Image_1.jpg  male       male        male
# 1  Image_2.jpg  male       male        male
# 2  Image_3.jpg  male       male        male
# 3  Image_4.jpg  male       male        male
# 4  Image_5.jpg  male       male        male

# %%
test_label_pred.label_pred.value_counts()
# Out:
# male      1339
# female     966
# Name: label_pred, dtype: int64

# %%
test_label_pred.label_pred3.to_csv("output3.csv", columns=['label_pred3'], index=False)

# %%
ptrain = model.predict(train_images)

# %%
ptn = np.argmax(ptrain, axis=1)

# %%
np.sum(ptn == train_label.label)/len(ptn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-3788b161f35b> in <module>
# ----> 1 np.sum(ptn == train_label.label)/len(ptn)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'label'

# %%
from keras.applications.resnet import ResNet50
from keras.preprocessing import image
from keras.applications.resnet import preprocess_input, decode_predictions
from keras.layers import * 
from keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
INPUT_SHAPE = (50, 50, 3)
model = ResNet50(include_top=False,weights='imagenet',input_shape=INPUT_SHAPE)
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 50, 50, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 56, 56, 3)    0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 25, 25, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 25, 25, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 25, 25, 64)   0           conv1_bn[0][0]
# ...

# %%
av1 = GlobalAveragePooling2D()(model.output)
fc1 = Dense(256,activation='relu')(av1)
d1 = Dropout(0.5)(fc1)
fc2 = Dense(2,activation='softmax')(d1)

model_new = Model(model.input,fc2)

model_new.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 50, 50, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 56, 56, 3)    0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 25, 25, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 25, 25, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 25, 25, 64)   0           conv1_bn[0][0]
# ...

# %%
for ix in range(len(model_new.layers)):
    pass
    #print(ix,model_new.layers[ix])

for ix in range(169):
    model_new.layers[ix].trainable = False
    
model_new.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 50, 50, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 56, 56, 3)    0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 25, 25, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 25, 25, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 25, 25, 64)   0           conv1_bn[0][0]
# ...

# %%
adam = Adam(learning_rate=0.00003)
model_new.compile(optimizer='adam',metrics=['accuracy'],loss='categorical_crossentropy')

# %%
es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2,
restore_best_weights=True,
verbose=1)

history = model_new.fit(
    train_images, train_label.label,
    batch_size=32,
    callbacks=[es_callback],
    validation_split=0.1, epochs=EPOCHS,
    verbose=1
)
# Out:
# Epoch 1/100
